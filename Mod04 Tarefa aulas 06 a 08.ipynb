# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %% [markdown]
# **1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.**

# %%
# 1) Seu código aqui

url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=MG&tipo_interessado=Estado'

# %%
r = requests.get(url)
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
data_json = r.json()
print(data_json['items'])
# Out:
# [{'id_pleito': 13595, 'tipo_interessado': 'Estado', 'interessado': 'Minas Gerais', 'cod_ibge': 31, 'uf': 'MG', 'num_pvl': None, 'status': 'Indeferido', 'num_processo': '19405.000033/2002-03', 'data_protocolo': '2002-05-28T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Renegociação de dívidas', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 53770000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '03/07/2002'}, {'id_pleito': 11054, 'tipo_interessado': 'Estado', 'interessado': 'Minas Gerais', 'cod_ibge': 31, 'uf': 'MG', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001346/2012-10', 'data_protocolo': '2012-10-29T02:00:00Z', 'tipo_operacao': 'Operação contratual interna (com garantia da União)', 'finalidade': 'Proinveste', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco
# ...

# %%
df = pd.DataFrame(data_json['items'])
df
# Out:
#     id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0       13595           Estado  Minas Gerais        31  MG
# 1       11054           Estado  Minas Gerais        31  MG
# 2        6917           Estado  Minas Gerais        31  MG
# 3       20458           Estado  Minas Gerais        31  MG
# 4        9197           Estado  Minas Gerais        31  MG
# 5        4926           Estado  Minas Gerais        31  MG
# 6       13618           Estado  Minas Gerais        31  MG
# 7        7280           Estado  Minas Gerais        31  MG
# 8       11328           Estado  Minas Gerais        31  MG
# 9       13549           Estado  Minas Gerais        31  MG
# 10      10294           Estado  Minas Gerais        31  MG
# 11       7419           Estado  Minas Gerais        31  MG
# 12       8255           Estado  Minas Gerais        31  MG
# 13       5828           Estado  Minas Gerais        31  MG
# 14       7435           Estado  Minas Gerais        31  MG
# ...

# %% [markdown]
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?

# %%
# 2) Seu código aqui
df['status'].value_counts().head(3)
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Name: status, dtype: int64

# %% [markdown]
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).

# %%
# 3) Seu código aqui
ano = df['data_status'].str.slice(start=6)
ano
# Out:
# 0     2002
# 1     2013
# 2     2012
# 3     2016
# 4     2010
# 5     2002
# 6     2009
# 7     2010
# 8     2013
# 9     2006
# 10    2013
# 11    2012
# 12    2014
# 13    2013
# 14    2009
# 15    2009
# 16    2008
# 17    2010
# 18    2006
# 19    2010
# 20    2009
# 21    2014
# 22    2005
# 23    2017
# 24    2009
# 25    2018
# 26    2004
# 27    2012
# 28    2016
# 29    2012
# 30    2017
# 31    2009
# 32    2006
# 33    2004
# 34    2004
# 35    2021
# 36    2011
# 37    2014
# 38    2010
# 39    2013
# Name: data_status, dtype: object

# %% [markdown]
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 4) Seu código aqui
ano.value_counts()
# Out:
# 2009    6
# 2013    5
# 2010    5
# 2012    4
# 2006    3
# 2014    3
# 2004    3
# 2002    2
# 2016    2
# 2017    2
# 2008    1
# 2005    1
# 2018    1
# 2021    1
# 2011    1
# Name: data_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.

# %%
#1) Seu código aqui
def Consulta(uf:str, tipo_interessado:str):
    import pandas as df
    import requests
    url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=' + uf + '&tipo_interessado=' + tipo_interessado
    r2 = requests.get(url)
    data_jason2 = r2.json()
    return(df.DataFrame(data_jason2['items']))

Consulta('MG', 'Município')
# Out:
#       id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 0          9982        Município    Campina Verde   3111101  MG
# 1          9986        Município        Rio Acima   3154804  MG
# 2          9997        Município              Ubá   3169901  MG
# 3         10015        Município         Cristais   3120201  MG
# 4          9924        Município            Ipaba   3131158  MG
# ...         ...              ...              ...       ...  ..
# 4303      22713        Município      Divinópolis   3122306  MG
# 4304      28588        Município          Iturama   3134400  MG
# 4305      26338        Município     Itamarandiba   3132503  MG
# 4306      27632        Município           Pompéu   3152006  MG
# 4307      27633        Município  Várzea da Palma   3170800  MG
#
#                    num_pvl             status          num_processo  \
# 0                     None           Deferido  17944.001093/2010-12
# ...

# %% [markdown]
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?

# %%
# 2) Seu código aqui
cons = Consulta('MG', 'Estado')
cons[(cons['status']=='Arquivado por decurso de prazo')]['status'].value_counts()
# Out:
# Arquivado por decurso de prazo    1
# Name: status, dtype: int64

# %% [markdown]
# 3. Qual é o município da Bahia com mais solicitações deferidas?

# %%
# 3) Seu código aqui
cons_ba = Consulta('BA', 'Município')
cons_ba['status']
cons_ba[(cons_ba['status']=='Deferido')][['status','interessado']].value_counts().head(1)
# Out:
# status    interessado
# Deferido  Luís Eduardo Magalhães    14
# dtype: int64

# %% [markdown]
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
# 4) Seu código aqui
cons_csv = Consulta('BA', 'Estado')
cons_csv.to_csv('/Users/eider/Desktop/EBAC/Ciência de Dados/CIENTISTA DE DADOS/Módulo 4/Consulta.csv')
